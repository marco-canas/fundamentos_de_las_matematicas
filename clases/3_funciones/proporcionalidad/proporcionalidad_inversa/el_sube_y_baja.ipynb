# %% [markdown]
# <table align="left">
#   <td>
# <a href="https://colab.research.google.com/github/marco-canas/fundamentos-de-las-matematicas/blob/main/clases/3_funciones/proporcionalidad/proporcionalidad_inversa/el_sube_y_baja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#  </td>
# </table>

# %% [markdown]
# ## [Video de apoyo en el canal DIMATHDATA](https://www.youtube.com/watch?v=qGCLtLnMtWc)

# %% [markdown]
# # ¿Qué es un modelo?
#
# Es la expresión matemática de un patrón o regunaridad observada en una situación problemática real (Marco Julio Cañas 2022)

# %% [markdown]
# # El doble le toca la mitad. Proporcionalidad inversa con Pandas, numpy y Matplotlib

# %% [markdown]
# ## La situación real que nos permitirá definir cuando una relación entre dos variables es de proporcionalidad inversa.

# %% [markdown]
# Para realizar una obra 10 obreros tardan 30 días. Y si queremos acelerar la entrega de la obra, vemos que si tidos los obreros trabajn con el mimo rendimiento, el duplicar el número de obreros a 20, hará que la obra se demore la mitad del tiempo previsto, es decir, 20 obreros se demorarán 15 días.

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True

dict_ = {r'obreros o': np.array([10, 20]), r'tiempo en realizar la obra t(días)': np.array([30, 15])}
tabla = pd.DataFrame(dict_)
tabla
# Out:
#    obreros o  tiempo en realizar la obra t(días)
# 0         10                                  30
# 1         20                                  15

# %% [markdown]
# # Modelo deducido de la tabla
#
# $$ ot = 300 = k: \text{constante de proporcionalidad} $$

# %% [markdown]
# # gráfica de este modelo

# %%
import numpy as np 

import matplotlib.pyplot as plt 

O = np.arange(0.01, 1, 0.01)
T = 300/O 

plt.plot(O, T)

# %% [markdown]
# Vemos que la representación gráfica de un modelo de proporcionalidad inversa es la de una hipérbola decreciente.

# %% [markdown]
# ## Interpretaciones o inferencias que se derivan de la lectura de la tabla
#
# * La tablas o representaciones tabulares de las relaciones entre dos variables se leen de manera vertical de arriba hacia abajo y comparando los comportamientos de crecimiento y decrecimiento por columnas.
#
# * La relación entre las variables o y t es decreciente pues al aumentar el número de obreros, el tiempo para realizar la misma obra disminuye.
# * La relación , además de decreciente es de proporcionalidad inversa porque al doble le toca la mitad. Es decir, el doble de obreros se tardan la mitad del tiempo.

# %% [markdown]
# # Una representación en diagrama de dispersión de la relación

# %%
import numpy as np 

import matplotlib.pyplot as plt 

O = np.array([10, 20, 40, 80])
T = np.array([30, 15, 7.5, 3.75])

plt.figure(figsize = (8, 8))

plt.title('Representación gráfica de una relación de proporcionalidad inversa')
plt.grid(alpha = 0.4) 
plt.xlabel('Número de obreros $o$')
plt.ylabel('Tiempo que tardan en realizar la obra $t$ (días)')

plt.axis([5, 85, 0,40]) # hemos escalado los ejes 

plt.scatter(O, T, color = 'red') 
plt.plot(O, T, color = 'green')  

plt.yticks(np.arange(0, 40, 1.25)) # cambiamos la metrización en el eje vertical. 

plt.savefig('proporcionalidad_inversa.jpg')

plt.show()

# %% [markdown]
# ## inferencias o interpretaciones que se derivan de la lectura del gráfico
#
# * La relación entre estas dos variables es decreciente más no lineal. Decreciente, porque al leler el gráfico de izquierda a derecha, los puntos de datos van perdiendo altura lo que se interpreta como que el tiempo disminuye a medida que el número de obreros aumenta.
#
# * Esta relación decreciente es además de proporcionalidad inversa porque al duplicar los valores de las abscisasm  los tiempos correspondientes se reducen a la mitad.

# %%
3.75*2
# Out:
# 7.5

# %% [markdown]
# ## Ejemplo de una relación decreciente que no es de proporcionalidad inversa
#
# La Ley de Demanda
#
# La ley de demanda es un principio económico que afirma que existe una relación inversa entre el precio de un bien y la cantidad demandada del mismo. Es decir, cuando el precio de un bien aumenta, la cantidad demandada del mismo disminuye. En la función de demanda, esto está representado por la pendiente negativa de la curva de demanda. En la función de demanda linear, la ley de demanda está representada por el coeficiente negativo -b.
#
# $$ Q = -bp + k \iff y = mx + b $$

# %% [markdown]
# Conclusión, no toda relación decreciente es de proporcionalidad inversa. Una relación entre dos variables es decreciente cuando al aumentar la una, la otra por el contrario disminuye. Además, una relación decreciente es de proporcionalidad inversa cuando al doble de la que aumenta le corresponde una disminución a la mital de la que se hace más pequeña.

# %% [markdown]
# # Situación problemática del Sube y Baja (Juego infantil tradicional)

# %% [markdown]
# <img src = 'https://github.com/marco-canas/fundamentos-de-las-matematicas/blob/main/clases/3_funciones/proporcionalidad/proporcionalidad_inversa/sube_y_baja.png?raw=true'>

# %% [markdown]
# 31. Ley de la palanca En la figura se ilustra un sistema de palancas, similar al sube y baja que usted encuentra en los parques para niños. Para que el sistema se equilibre, el producto del peso por la distancia a partir del punto de apoyo debe ser igual en cada lado. Es decir,
#
# $$ w_{1}x_{1} = w_{2}x_{2} $$
#
# Esta ecuación recibe el nombre de ley de la palanca, y fue descubierta por Arquímedes (véase la pág. 748).
#
#
#
# Una mujer y su hijo están jugando en un sube y baja. El muchacho está en un extremo, a 8 pies del punto de apoyo.
#
# Si el hijo pesa 100 libras y la madre pesa 125 libras, ¿dónde debe colocarse la mujer para equilibrar el sube y baja?

# %% [markdown]
# ## Solución del problema

# %% [markdown]
# La constante de proporcionalidad es:
#
# $$ k = w_{1}x_{1} = 100(8) \ \text{libras por pies} $$

# %% [markdown]
# El modelo es
#
# $$ f(x) = 125x = 800 $$

# %% [markdown]
# ## Gráfica del modelo

# %% [markdown]
# ## Solución del problema a partir de la lectura del gráfico del modelo de proporcionalidad inversa

# %%
from proporcionalidad import visualizar_funcion

visualizar_funcion()

# %% [markdown]
# ## Referentes
#
# * El doble le toca el doble:
