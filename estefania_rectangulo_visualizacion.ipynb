# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-canas/fundamentos-de-las-matematicas/blob/main/estefania_rectangulo_visualizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Solución gráfica de ecuaciones

# %% [markdown]
# 1. Utilice una calculadora para graficar o una computadora para decidir que rectangulo de visión a) a d) genera la gráfica más adecuada de la ecuación.
#
# 1. $y=x^{4}+2$
#
# a) $[-2,2]$ por $[-2,2]$
#
# b)[0,4]por[0,4]
#
# c)[-8,8]por[-4,40]
#
# d)[-40,40]por[-80,800]

# %% [markdown]
# ##Solución

# %%
import numpy as np 
import pandas as pd
X = np.arange(-2,3)
Y = X**4+2
diccionario_datos = {'abscisas $x$': X, 'ordenadas $y$':Y}
representacion_tabular = pd.DataFrame(diccionario_datos)
representacion_tabular
# Out:
#    abscisas $x$  ordenadas $y$
# 0            -2             18
# 1            -1              3
# 2             0              2
# 3             1              3
# 4             2             18

# %%
from numpy import is_busday
import matplotlib.pyplot as plt

plt.scatter (X,Y, color = 'red')
plt.plot ([-2,-1,0,1,2],[18,3,2,3,18])

plt.show()

# %% [markdown]
# $18.$ Determine un rectángulo de visión adecuado para la
# ecuación y utilícelo para trazar la gráfica.
#
# $y=2x-|x^2-5|$
#
# ![Captura de pantalla 2022-09-11 161244.png](data:image/png;base64,...)
#
# $y=2(-6)-|-6^2-5|$
#
# $y=-12-|36-5|$
#
# $y=-12-31$
#
# $y=-43$
#
# ![Captura de pantalla 2022-09-11 161112.png](data:image/png;base64,...)
#
#
# ![descarga.png](data:image/png;base64,...)
