# %% [markdown]
# # Ejercicio 1 sobre números reales
#
# 1. Diga si cada una de las desigualdades es verdadera o falsa.
#
#   a. $ -3 < -15$

# %%
-3<-15
# Out:
# False

# %% [markdown]
# Entonces -3 no es menor que menos -15. Por lo tanto, la desigualdad dada es falsa.
